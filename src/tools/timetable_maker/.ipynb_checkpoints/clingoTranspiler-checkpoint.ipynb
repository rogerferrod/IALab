# %% [markdown]
# # Clingo Transpiler
#
# A simple Jupyter Notebook that takes as input the clingo output file (for our convention called "out.txt") and produce as output an excel file, containing the trascription as a timetable of the clingo output.

# %%
import numpy as np
import pandas as pd
import xlsxwriter
import re
from collections import namedtuple
import sys

# %% [markdown]
# ## The Parser: the core of the notebook

# %%
# Path to the clingo output file
input_file = "../../asp/output/out.txt"

Calendar = namedtuple("Calendar",["week","day","hour","id","lecture","professor"]) 
with open(input_file,"r") as file:
    lines = file.read()
    
    # Parser specification:
    # we use a regex to match the answer set
    regex_predicate = re.compile("calendar\((\d+),(\d+),(\d+),(\d+),\"([\w\s:-]+)\",\"([\w\s:-]*)\"\)")
    regex_top_level = re.compile("(Answer: [\d]+)\n(.+)")


    # Parsing two hardcoded nested levels: 
    # lvl 1) multiple answer-set
    parsed_content = {}
    for answer_set_match in re.finditer(regex_top_level,lines):
        answer_set_name = answer_set_match.groups()[0]
        answer_set =  answer_set_match.groups()[1]
        
        # lvl 2) predicates
        predicates = [Calendar._make(predicate_match.groups()) for predicate_match in re.finditer(regex_predicate,answer_set)]
        
        # build dictionary of parsed answer-sets (normalizing the key value)
        parsed_content[answer_set_name.replace(": ","_")] = predicates

# %%
# Checking the values inside parsed_content
parsed_content
# Out:
# {'Answer_1': [Calendar(week='1', day='5', hour='1', id='151', lecture='Intro', professor=''),
#   Calendar(week='1', day='5', hour='2', id='152', lecture='Intro', professor=''),
#   Calendar(week='6', day='5', hour='2', id='652', lecture='Recupero', professor=''),
#   Calendar(week='6', day='6', hour='2', id='662', lecture='Recupero', professor=''),
#   Calendar(week='6', day='6', hour='3', id='663', lecture='Recupero', professor=''),
#   Calendar(week='5', day='6', hour='5', id='565', lecture='Recupero', professor=''),
#   Calendar(week='2', day='5', hour='1', id='251', lecture='Project Management', professor='Muzzetto'),
#   Calendar(week='3', day='5', hour='1', id='351', lecture='Project Management', professor='Muzzetto'),
#   Calendar(week='2', day='5', hour='2', id='252', lecture='Project Management', professor='Muzzetto'),
#   Calendar(week='3', day='5', hour='2', id='352', lecture='Project Management', professor='Muzzetto'),
#   Calendar(week='3', day='5', hour='3', id='353', lecture='Project Management', professor='Muzzetto'),
#   Calendar(week='1', day='5', hour='4', id='154', lecture='Project Management', professor='Muzzetto'),
#   Calendar(week='5', day='5', hour='4', id='554', lecture='Project Management', professor='Muzzetto'),
#   Calendar(week='1', day='5', hour='5', id='155', lecture='Project Management', professor='Muzzetto'),
#   Calendar(week='4', day='5', hour='5', id='455', lecture='Project Management', professor='Muzzetto'),
#   Calendar(week='1', day='5', hour='6', id='156', lecture='Project Management', professor='Muzzetto'),
#   Calendar(week='2', day='5', hour='6', id='256', lecture='Project Management', professor='Muzzetto'),
#   Calendar(week='2', day='5', hour='7', id='257', lecture='Project Management', professor='Muzzetto'),
#   Calendar(week='5', day='6', hour='2', id='562', lecture='Project Management', professor='Muzzetto'),
#   Calendar(week='2', day='6', hour='3', id='263', lecture='Project Management', professor='Muzzetto'),
#   Calendar(week='4', day='5', hour='1', id='451', lecture='Fondamenti di ICT e Paradigmi di Programmazione', professor='Pozzato'),
#   Calendar(week='4', day='5', hour='2', id='452', lecture='Fondamenti di ICT e Paradigmi di Programmazione', professor='Pozzato'),
#   Calendar(week='1', day='5', hour='3', id='153', lecture='Fondamenti di ICT e Paradigmi di Programmazione', professor='Pozzato'),
#   Calendar(week='3', day='5', hour='4', id='354', lecture='Fondamenti di ICT e Paradigmi di Programmazione', professor='Pozzato'),
#   Calendar(week='4', day='5', hour='4', id='454', lecture='Fondamenti di ICT e Paradigmi di Programmazione', professor='Pozzato'),
#   Calendar(week='2', day='5', hour='5', id='255', lecture='Fondamenti di ICT e Paradigmi di Programmazione', professor='Pozzato'),
#   Calendar(week='3', day='5', hour='5', id='355', lecture='Fondamenti di ICT e Paradigmi di Programmazione', professor='Pozzato'),
#   Calendar(week='1', day='5', hour='7', id='157', lecture='Fondamenti di ICT e Paradigmi di Programmazione', professor='Pozzato'),
#   Calendar(week='3', day='5', hour='7', id='357', lecture='Fondamenti di ICT e Paradigmi di Programmazione', professor='Pozzato'),
#   Calendar(week='1', day='5', hour='8', id='158', lecture='Fondamenti di ICT e Paradigmi di Programmazione', professor='Pozzato'),
#   Calendar(week='3', day='5', hour='8', id='358', lecture='Fondamenti di ICT e Paradigmi di Programmazione', professor='Pozzato'),
#   Calendar(week='1', day='6', hour='1', id='161', lecture='Fondamenti di ICT e Paradigmi di Programmazione', professor='Pozzato'),
#   Calendar(week='3', day='6', hour='1', id='361', lecture='Fondamenti di ICT e Paradigmi di Programmazione', professor='Pozzato'),
#   Calendar(week='3', day='6', hour='3', id='363', lecture='Fondamenti di ICT e Paradigmi di Programmazione', professor='Pozzato'),
#   Calendar(week='7', day='1', hour='2', id='712', lecture='Linguaggi di markup', professor='Gena'),
#   Calendar(week='7', day='1', hour='6', id='716', lecture='Linguaggi di markup', professor='Gena'),
#   Calendar(week='7', day='2', hour='2', id='722', lecture='Linguaggi di markup', professor='Gena'),
#   Calendar(week='7', day='2', hour='8', id='728', lecture='Linguaggi di markup', professor='Gena'),
#   Calendar(week='7', day='3', hour='3', id='733', lecture='Linguaggi di markup', professor='Gena'),
#   Calendar(week='7', day='3', hour='5', id='735', lecture='Linguaggi di markup', professor='Gena'),
#   Calendar(week='7', day='3', hour='6', id='736', lecture='Linguaggi di markup', professor='Gena'),
#   Calendar(week='7', day='4', hour='3', id='743', lecture='Linguaggi di markup', professor='Gena'),
#   Calendar(week='7', day='4', hour='4', id='744', lecture='Linguaggi di markup', professor='Gena'),
#   Calendar(week='7', day='4', hour='5', id='745', lecture='Linguaggi di markup', professor='Gena'),
#   Calendar(week='9', day='5', hour='1', id='951', lecture='Linguaggi di markup', professor='Gena'),
#   Calendar(week='7', day='5', hour='2', id='752', lecture='Linguaggi di markup', professor='Gena'),
#   Calendar(week='9', day='5', hour='6', id='956', lecture='Linguaggi di markup', professor='Gena'),
#   Calendar(week='10', day='5', hour='6', id='1056', lecture='Linguaggi di markup', professor='Gena'),
#   Calendar(week='7', day='5', hour='7', id='757', lecture='Linguaggi di markup', professor='Gena'),
#   Calendar(week='7', day='5', hour='8', id='758', lecture='Linguaggi di markup', professor='Gena'),
#   Calendar(week='9', day='5', hour='8', id='958', lecture='Linguaggi di markup', professor='Gena'),
#   Calendar(week='10', day='5', hour='8', id='1058', lecture='Linguaggi di markup', professor='Gena'),
#   Calendar(week='8', day='6', hour='1', id='861', lecture='Linguaggi di markup', professor='Gena'),
#   Calendar(week='6', day='6', hour='5', id='665', lecture='Linguaggi di markup', professor='Gena'),
#   Calendar(week='16', day='2', hour='7', id='1627', lecture='La gestione della qualità', professor='Tomatis'),
#   Calendar(week='17', day='5', hour='1', id='1751', lecture='La gestione della qualità', professor='Tomatis'),
#   Calendar(week='19', day='5', hour='1', id='1951', lecture='La gestione della qualità', professor='Tomatis'),
#   Calendar(week='21', day='5', hour='1', id='2151', lecture='La gestione della qualità', professor='Tomatis'),
#   Calendar(week='18', day='5', hour='2', id='1852', lecture='La gestione della qualità', professor='Tomatis'),
#   Calendar(week='22', day='5', hour='2', id='2252', lecture='La gestione della qualità', professor='Tomatis'),
#   Calendar(week='22', day='5', hour='3', id='2253', lecture='La gestione della qualità', professor='Tomatis'),
#   Calendar(week='22', day='5', hour='5', id='2255', lecture='La gestione della qualità', professor='Tomatis'),
#   Calendar(week='16', day='5', hour='8', id='1658', lecture='La gestione della qualità', professor='Tomatis'),
#   Calendar(week='17', day='6', hour='2', id='1762', lecture='La gestione della qualità', professor='Tomatis'),
#   Calendar(week='7', day='3', hour='4', id='734', lecture='Ambienti di sviluppo e linguaggi client-side per il web', professor='Micalizio'),
#   Calendar(week='7', day='3', hour='7', id='737', lecture='Ambienti di sviluppo e linguaggi client-side per il web', professor='Micalizio'),
#   Calendar(week='7', day='3', hour='8', id='738', lecture='Ambienti di sviluppo e linguaggi client-side per il web', professor='Micalizio'),
#   Calendar(week='7', day='4', hour='1', id='741', lecture='Ambienti di sviluppo e linguaggi client-side per il web', professor='Micalizio'),
#   Calendar(week='7', day='4', hour='2', id='742', lecture='Ambienti di sviluppo e linguaggi client-side per il web', professor='Micalizio'),
#   Calendar(week='7', day='4', hour='6', id='746', lecture='Ambienti di sviluppo e linguaggi client-side per il web', professor='Micalizio'),
#   Calendar(week='5', day='5', hour='1', id='551', lecture='Ambienti di sviluppo e linguaggi client-side per il web', professor='Micalizio'),
#   Calendar(week='5', day='5', hour='2', id='552', lecture='Ambienti di sviluppo e linguaggi client-side per il web', professor='Micalizio'),
#   Calendar(week='5', day='5', hour='3', id='553', lecture='Ambienti di sviluppo e linguaggi client-side per il web', professor='Micalizio'),
#   Calendar(week='8', day='5', hour='3', id='853', lecture='Ambienti di sviluppo e linguaggi client-side per il web', professor='Micalizio'),
#   Calendar(week='8', day='5', hour='4', id='854', lecture='Ambienti di sviluppo e linguaggi client-side per il web', professor='Micalizio'),
#   Calendar(week='9', day='5', hour='4', id='954', lecture='Ambienti di sviluppo e linguaggi client-side per il web', professor='Micalizio'),
#   Calendar(week='5', day='5', hour='5', id='555', lecture='Ambienti di sviluppo e linguaggi client-side per il web', professor='Micalizio'),
#   Calendar(week='4', day='5', hour='6', id='456', lecture='Ambienti di sviluppo e linguaggi client-side per il web', professor='Micalizio'),
#   Calendar(week='4', day='5', hour='7', id='457', lecture='Ambienti di sviluppo e linguaggi client-side per il web', professor='Micalizio'),
#   Calendar(week='4', day='5', hour='8', id='458', lecture='Ambienti di sviluppo e linguaggi client-side per il web', professor='Micalizio'),
#   Calendar(week='5', day='6', hour='1', id='561', lecture='Ambienti di sviluppo e linguaggi client-side per il web', professor='Micalizio'),
#   Calendar(week='4', day='6', hour='2', id='462', lecture='Ambienti di sviluppo e linguaggi client-side per il web', professor='Micalizio'),
#   Calendar(week='5', day='6', hour='3', id='563', lecture='Ambienti di sviluppo e linguaggi client-side per il web', professor='Micalizio'),
#   Calendar(week='5', day='6', hour='4', id='564', lecture='Ambienti di sviluppo e linguaggi client-side per il web', professor='Micalizio'),
#   Calendar(week='23', day='5', hour='3', id='2353', lecture='Progettazione grafica e design di interfacce', professor='Terranova'),
#   Calendar(week='23', day='5', hour='4', id='2354', lecture='Progettazione grafica e design di interfacce', professor='Terranova'),
#   Calendar(week='18', day='5', hour='6', id='1856', lecture='Progettazione grafica e design di interfacce', professor='Terranova'),
#   Calendar(week='19', day='5', hour='6', id='1956', lecture='Progettazione grafica e design di interfacce', professor='Terranova'),
#   Calendar(week='23', day='5', hour='6', id='2356', lecture='Progettazione grafica e design di interfacce', professor='Terranova'),
#   Calendar(week='18', day='5', hour='7', id='1857', lecture='Progettazione grafica e design di interfacce', professor='Terranova'),
#   Calendar(week='19', day='5', hour='7', id='1957', lecture='Progettazione grafica e design di interfacce', professor='Terranova'),
#   Calendar(week='23', day='5', hour='7', id='2357', lecture='Progettazione grafica e design di interfacce', professor='Terranova'),
#   Calendar(week='17', day='6', hour='1', id='1761', lecture='Progettazione grafica e design di interfacce', professor='Terranova'),
#   Calendar(week='17', day='6', hour='5', id='1765', lecture='Progettazione grafica e design di interfacce', professor='Terranova'),
#   Calendar(week='2', day='5', hour='3', id='253', lecture='Progettazione di basi di dati', professor='Mazzei'),
#   Calendar(week='4', day='5', hour='3', id='453', lecture='Progettazione di basi di dati', professor='Mazzei'),
#   Calendar(week='2', day='5', hour='4', id='254', lecture='Progettazione di basi di dati', professor='Mazzei'),
#   Calendar(week='3', day='5', hour='6', id='356', lecture='Progettazione di basi di dati', professor='Mazzei'),
#   Calendar(week='2', day='5', hour='8', id='258', lecture='Progettazione di basi di dati', professor='Mazzei'),
#   Calendar(week='2', day='6', hour='1', id='261', lecture='Progettazione di basi di dati', professor='Mazzei'),
#   Calendar(week='4', day='6', hour='1', id='461', lecture='Progettazione di basi di dati', professor='Mazzei'),
#   Calendar(week='1', day='6', hour='2', id='162', lecture='Progettazione di basi di dati', professor='Mazzei'),
#   Calendar(week='2', day='6', hour='2', id='262', lecture='Progettazione di basi di dati', professor='Mazzei'),
#   Calendar(week='3', day='6', hour='2', id='362', lecture='Progettazione di basi di dati', professor='Mazzei'),
#   Calendar(week='1', day='6', hour='3', id='163', lecture='Progettazione di basi di dati', professor='Mazzei'),
#   Calendar(week='4', day='6', hour='3', id='463', lecture='Progettazione di basi di dati', professor='Mazzei'),
#   Calendar(week='1', day='6', hour='4', id='164', lecture='Progettazione di basi di dati', professor='Mazzei'),
#   Calendar(week='2', day='6', hour='4', id='264', lecture='Progettazione di basi di dati', professor='Mazzei'),
#   Calendar(week='3', day='6', hour='4', id='364', lecture='Progettazione di basi di dati', professor='Mazzei'),
#   Calendar(week='4', day='6', hour='4', id='464', lecture='Progettazione di basi di dati', professor='Mazzei'),
#   Calendar(week='1', day='6', hour='5', id='165', lecture='Progettazione di basi di dati', professor='Mazzei'),
#   Calendar(week='2', day='6', hour='5', id='265', lecture='Progettazione di basi di dati', professor='Mazzei'),
#   Calendar(week='3', day='6', hour='5', id='365', lecture='Progettazione di basi di dati', professor='Mazzei'),
#   Calendar(week='4', day='6', hour='5', id='465', lecture='Progettazione di basi di dati', professor='Mazzei'),
#   Calendar(week='16', day='1', hour='2', id='1612', lecture='Strumenti e metodi di interazione nei Social media', professor='Giordani'),
#   Calendar(week='16', day='2', hour='5', id='1625', lecture='Strumenti e metodi di interazione nei Social media', professor='Giordani'),
#   Calendar(week='16', day='3', hour='4', id='1634', lecture='Strumenti e metodi di interazione nei Social media', professor='Giordani'),
#   Calendar(week='16', day='4', hour='6', id='1646', lecture='Strumenti e metodi di interazione nei Social media', professor='Giordani'),
#   Calendar(week='10', day='5', hour='1', id='1051', lecture='Strumenti e metodi di interazione nei Social media', professor='Giordani'),
#   Calendar(week='10', day='5', hour='2', id='1052', lecture='Strumenti e metodi di interazione nei Social media', professor='Giordani'),
#   Calendar(week='11', day='5', hour='4', id='1154', lecture='Strumenti e metodi di interazione nei Social media', professor='Giordani'),
#   Calendar(week='16', day='5', hour='4', id='1654', lecture='Strumenti e metodi di interazione nei Social media', professor='Giordani'),
#   Calendar(week='16', day='5', hour='5', id='1655', lecture='Strumenti e metodi di interazione nei Social media', professor='Giordani'),
#   Calendar(week='15', day='5', hour='6', id='1556', lecture='Strumenti e metodi di interazione nei Social media', professor='Giordani'),
#   Calendar(week='16', day='5', hour='7', id='1657', lecture='Strumenti e metodi di interazione nei Social media', professor='Giordani'),
#   Calendar(week='14', day='5', hour='8', id='1458', lecture='Strumenti e metodi di interazione nei Social media', professor='Giordani'),
#   Calendar(week='16', day='6', hour='2', id='1662', lecture='Strumenti e metodi di interazione nei Social media', professor='Giordani'),
#   Calendar(week='15', day='6', hour='3', id='1563', lecture='Strumenti e metodi di interazione nei Social media', professor='Giordani'),
#   Calendar(week='7', day='2', hour='1', id='721', lecture='Acquisizione ed elaborazione di immagini statiche - grafica', professor='Zanchetta'),
#   Calendar(week='7', day='2', hour='7', id='727', lecture='Acquisizione ed elaborazione di immagini statiche - grafica', professor='Zanchetta'),
#   Calendar(week='7', day='3', hour='2', id='732', lecture='Acquisizione ed elaborazione di immagini statiche - grafica', professor='Zanchetta'),
#   Calendar(week='7', day='4', hour='8', id='748', lecture='Acquisizione ed elaborazione di immagini statiche - grafica', professor='Zanchetta'),
#   Calendar(week='7', day='5', hour='5', id='755', lecture='Acquisizione ed elaborazione di immagini statiche - grafica', professor='Zanchetta'),
#   Calendar(week='7', day='5', hour='6', id='756', lecture='Acquisizione ed elaborazione di immagini statiche - grafica', professor='Zanchetta'),
#   Calendar(week='9', day='5', hour='7', id='957', lecture='Acquisizione ed elaborazione di immagini statiche - grafica', professor='Zanchetta'),
#   Calendar(week='8', day='6', hour='2', id='862', lecture='Acquisizione ed elaborazione di immagini statiche - grafica', professor='Zanchetta'),
#   Calendar(week='9', day='6', hour='2', id='962', lecture='Acquisizione ed elaborazione di immagini statiche - grafica', professor='Zanchetta'),
#   Calendar(week='7', day='6', hour='3', id='763', lecture='Acquisizione ed elaborazione di immagini statiche - grafica', professor='Zanchetta'),
#   Calendar(week='9', day='6', hour='3', id='963', lecture='Acquisizione ed elaborazione di immagini statiche - grafica', professor='Zanchetta'),
#   Calendar(week='6', day='6', hour='4', id='664', lecture='Acquisizione ed elaborazione di immagini statiche - grafica', professor='Zanchetta'),
#   Calendar(week='7', day='6', hour='4', id='764', lecture='Acquisizione ed elaborazione di immagini statiche - grafica', professor='Zanchetta'),
#   Calendar(week='9', day='6', hour='4', id='964', lecture='Acquisizione ed elaborazione di immagini statiche - grafica', professor='Zanchetta'),
#   Calendar(week='8', day='5', hour='2', id='852', lecture='Accessibilità e usabilità nella progettazione multimediale', professor='Gena'),
#   Calendar(week='10', day='5', hour='4', id='1054', lecture='Accessibilità e usabilità nella progettazione multimediale', professor='Gena'),
#   Calendar(week='12', day='5', hour='4', id='1254', lecture='Accessibilità e usabilità nella progettazione multimediale', professor='Gena'),
#   Calendar(week='6', day='5', hour='5', id='655', lecture='Accessibilità e usabilità nella progettazione multimediale', professor='Gena'),
#   Calendar(week='12', day='5', hour='5', id='1255', lecture='Accessibilità e usabilità nella progettazione multimediale', professor='Gena'),
#   Calendar(week='8', day='5', hour='6', id='856', lecture='Accessibilità e usabilità nella progettazione multimediale', professor='Gena'),
#   Calendar(week='12', day='5', hour='6', id='1256', lecture='Accessibilità e usabilità nella progettazione multimediale', professor='Gena'),
#   Calendar(week='11', day='5', hour='7', id='1157', lecture='Accessibilità e usabilità nella progettazione multimediale', professor='Gena'),
#   Calendar(week='11', day='5', hour='8', id='1158', lecture='Accessibilità e usabilità nella progettazione multimediale', professor='Gena'),
#   Calendar(week='9', day='6', hour='1', id='961', lecture='Accessibilità e usabilità nella progettazione multimediale', professor='Gena'),
#   Calendar(week='11', day='6', hour='1', id='1161', lecture='Accessibilità e usabilità nella progettazione multimediale', professor='Gena'),
#   Calendar(week='11', day='6', hour='2', id='1162', lecture='Accessibilità e usabilità nella progettazione multimediale', professor='Gena'),
#   Calendar(week='8', day='6', hour='4', id='864', lecture='Accessibilità e usabilità nella progettazione multimediale', professor='Gena'),
#   Calendar(week='7', day='6', hour='5', id='765', lecture='Accessibilità e usabilità nella progettazione multimediale', professor='Gena'),
#   Calendar(week='7', day='1', hour='1', id='711', lecture='Marketing digitale', professor='Muzzetto'),
#   Calendar(week='7', day='1', hour='4', id='714', lecture='Marketing digitale', professor='Muzzetto'),
#   Calendar(week='7', day='1', hour='5', id='715', lecture='Marketing digitale', professor='Muzzetto'),
#   Calendar(week='7', day='2', hour='5', id='725', lecture='Marketing digitale', professor='Muzzetto'),
#   Calendar(week='7', day='2', hour='6', id='726', lecture='Marketing digitale', professor='Muzzetto'),
#   Calendar(week='6', day='5', hour='1', id='651', lecture='Marketing digitale', professor='Muzzetto'),
#   Calendar(week='6', day='5', hour='4', id='654', lecture='Marketing digitale', professor='Muzzetto'),
#   Calendar(week='6', day='5', hour='6', id='656', lecture='Marketing digitale', professor='Muzzetto'),
#   Calendar(week='6', day='5', hour='8', id='658', lecture='Marketing digitale', professor='Muzzetto'),
#   Calendar(week='6', day='6', hour='1', id='661', lecture='Marketing digitale', professor='Muzzetto'),
#   Calendar(week='14', day='5', hour='6', id='1456', lecture='Elementi di fotografia digitale', professor='Vargiu'),
#   Calendar(week='17', day='5', hour='6', id='1756', lecture='Elementi di fotografia digitale', professor='Vargiu'),
#   Calendar(week='12', day='5', hour='7', id='1257', lecture='Elementi di fotografia digitale', professor='Vargiu'),
#   Calendar(week='13', day='5', hour='7', id='1357', lecture='Elementi di fotografia digitale', professor='Vargiu'),
#   Calendar(week='15', day='5', hour='7', id='1557', lecture='Elementi di fotografia digitale', professor='Vargiu'),
#   Calendar(week='15', day='5', hour='8', id='1558', lecture='Elementi di fotografia digitale', professor='Vargiu'),
#   Calendar(week='17', day='5', hour='8', id='1758', lecture='Elementi di fotografia digitale', professor='Vargiu'),
#   Calendar(week='15', day='6', hour='1', id='1561', lecture='Elementi di fotografia digitale', professor='Vargiu'),
#   Calendar(week='16', day='6', hour='1', id='1661', lecture='Elementi di fotografia digitale', professor='Vargiu'),
#   Calendar(week='18', day='6', hour='1', id='1861', lecture='Elementi di fotografia digitale', professor='Vargiu'),
#   Calendar(week='15', day='5', hour='3', id='1553', lecture='Risorse digitali per il progetto: collaborazione e documentazione', professor='Boniolo'),
#   Calendar(week='13', day='5', hour='4', id='1354', lecture='Risorse digitali per il progetto: collaborazione e documentazione', professor='Boniolo'),
#   Calendar(week='14', day='5', hour='4', id='1454', lecture='Risorse digitali per il progetto: collaborazione e documentazione', professor='Boniolo'),
#   Calendar(week='15', day='5', hour='4', id='1554', lecture='Risorse digitali per il progetto: collaborazione e documentazione', professor='Boniolo'),
#   Calendar(week='18', day='5', hour='4', id='1854', lecture='Risorse digitali per il progetto: collaborazione e documentazione', professor='Boniolo'),
#   Calendar(week='15', day='5', hour='5', id='1555', lecture='Risorse digitali per il progetto: collaborazione e documentazione', professor='Boniolo'),
#   Calendar(week='17', day='5', hour='5', id='1755', lecture='Risorse digitali per il progetto: collaborazione e documentazione', professor='Boniolo'),
#   Calendar(week='14', day='5', hour='7', id='1457', lecture='Risorse digitali per il progetto: collaborazione e documentazione', professor='Boniolo'),
#   Calendar(week='13', day='5', hour='8', id='1358', lecture='Risorse digitali per il progetto: collaborazione e documentazione', professor='Boniolo'),
#   Calendar(week='14', day='6', hour='3', id='1463', lecture='Risorse digitali per il progetto: collaborazione e documentazione', professor='Boniolo'),
#   Calendar(week='19', day='5', hour='2', id='1952', lecture='Tecnologie server-side per il web', professor='Damiano'),
#   Calendar(week='23', day='5', hour='2', id='2352', lecture='Tecnologie server-side per il web', professor='Damiano'),
#   Calendar(week='19', day='5', hour='4', id='1954', lecture='Tecnologie server-side per il web', professor='Damiano'),
#   Calendar(week='21', day='5', hour='4', id='2154', lecture='Tecnologie server-side per il web', professor='Damiano'),
#   Calendar(week='19', day='5', hour='5', id='1955', lecture='Tecnologie server-side per il web', professor='Damiano'),
#   Calendar(week='20', day='5', hour='5', id='2055', lecture='Tecnologie server-side per il web', professor='Damiano'),
#   Calendar(week='21', day='5', hour='6', id='2156', lecture='Tecnologie server-side per il web', professor='Damiano'),
#   Calendar(week='22', day='5', hour='6', id='2256', lecture='Tecnologie server-side per il web', professor='Damiano'),
#   Calendar(week='17', day='5', hour='7', id='1757', lecture='Tecnologie server-side per il web', professor='Damiano'),
#   Calendar(week='22', day='5', hour='7', id='2257', lecture='Tecnologie server-side per il web', professor='Damiano'),
#   Calendar(week='18', day='5', hour='8', id='1858', lecture='Tecnologie server-side per il web', professor='Damiano'),
#   Calendar(week='21', day='5', hour='8', id='2158', lecture='Tecnologie server-side per il web', professor='Damiano'),
#   Calendar(week='22', day='5', hour='8', id='2258', lecture='Tecnologie server-side per il web', professor='Damiano'),
#   Calendar(week='22', day='6', hour='1', id='2261', lecture='Tecnologie server-side per il web', professor='Damiano'),
#   Calendar(week='21', day='6', hour='2', id='2162', lecture='Tecnologie server-side per il web', professor='Damiano'),
#   Calendar(week='22', day='6', hour='2', id='2262', lecture='Tecnologie server-side per il web', professor='Damiano'),
#   Calendar(week='21', day='6', hour='3', id='2163', lecture='Tecnologie server-side per il web', professor='Damiano'),
#   Calendar(week='22', day='6', hour='3', id='2263', lecture='Tecnologie server-side per il web', professor='Damiano'),
#   Calendar(week='20', day='6', hour='4', id='2064', lecture='Tecnologie server-side per il web', professor='Damiano'),
#   Calendar(week='21', day='6', hour='4', id='2164', lecture='Tecnologie server-side per il web', professor='Damiano'),
#   Calendar(week='7', day='3', hour='1', id='731', lecture='Tecniche e strumenti di Marketing digitale', professor='Zanchetta'),
#   Calendar(week='7', day='4', hour='7', id='747', lecture='Tecniche e strumenti di Marketing digitale', professor='Zanchetta'),
#   Calendar(week='7', day='5', hour='1', id='751', lecture='Tecniche e strumenti di Marketing digitale', professor='Zanchetta'),
#   Calendar(week='8', day='5', hour='1', id='851', lecture='Tecniche e strumenti di Marketing digitale', professor='Zanchetta'),
#   Calendar(week='13', day='5', hour='3', id='1353', lecture='Tecniche e strumenti di Marketing digitale', professor='Zanchetta'),
#   Calendar(week='8', day='5', hour='8', id='858', lecture='Tecniche e strumenti di Marketing digitale', professor='Zanchetta'),
#   Calendar(week='7', day='6', hour='1', id='761', lecture='Tecniche e strumenti di Marketing digitale', professor='Zanchetta'),
#   Calendar(week='7', day='6', hour='2', id='762', lecture='Tecniche e strumenti di Marketing digitale', professor='Zanchetta'),
#   Calendar(week='8', day='6', hour='3', id='863', lecture='Tecniche e strumenti di Marketing digitale', professor='Zanchetta'),
#   Calendar(week='8', day='6', hour='5', id='865', lecture='Tecniche e strumenti di Marketing digitale', professor='Zanchetta'),
#   Calendar(week='16', day='1', hour='5', id='1615', lecture='Introduzione al social media management', professor='Suppini'),
#   Calendar(week='16', day='1', hour='6', id='1616', lecture='Introduzione al social media management', professor='Suppini'),
#   Calendar(week='16', day='1', hour='7', id='1617', lecture='Introduzione al social media management', professor='Suppini'),
#   Calendar(week='16', day='1', hour='8', id='1618', lecture='Introduzione al social media management', professor='Suppini'),
#   Calendar(week='16', day='2', hour='2', id='1622', lecture='Introduzione al social media management', professor='Suppini'),
#   Calendar(week='16', day='2', hour='3', id='1623', lecture='Introduzione al social media management', professor='Suppini'),
#   Calendar(week='16', day='2', hour='4', id='1624', lecture='Introduzione al social media management', professor='Suppini'),
#   Calendar(week='16', day='2', hour='6', id='1626', lecture='Introduzione al social media management', professor='Suppini'),
#   Calendar(week='16', day='3', hour='1', id='1631', lecture='Introduzione al social media management', professor='Suppini'),
#   Calendar(week='16', day='3', hour='3', id='1633', lecture='Introduzione al social media management', professor='Suppini'),
#   Calendar(week='16', day='3', hour='6', id='1636', lecture='Introduzione al social media management', professor='Suppini'),
#   Calendar(week='16', day='4', hour='1', id='1641', lecture='Introduzione al social media management', professor='Suppini'),
#   Calendar(week='16', day='4', hour='2', id='1642', lecture='Introduzione al social media management', professor='Suppini'),
#   Calendar(week='16', day='4', hour='5', id='1645', lecture='Introduzione al social media management', professor='Suppini'),
#   Calendar(week='13', day='5', hour='1', id='1351', lecture='Acquisizione ed elaborazione del suono', professor='Valle'),
#   Calendar(week='14', day='5', hour='1', id='1451', lecture='Acquisizione ed elaborazione del suono', professor='Valle'),
#   Calendar(week='15', day='5', hour='1', id='1551', lecture='Acquisizione ed elaborazione del suono', professor='Valle'),
#   Calendar(week='13', day='5', hour='2', id='1352', lecture='Acquisizione ed elaborazione del suono', professor='Valle'),
#   Calendar(week='14', day='5', hour='2', id='1452', lecture='Acquisizione ed elaborazione del suono', professor='Valle'),
#   Calendar(week='15', day='5', hour='2', id='1552', lecture='Acquisizione ed elaborazione del suono', professor='Valle'),
#   Calendar(week='14', day='5', hour='3', id='1453', lecture='Acquisizione ed elaborazione del suono', professor='Valle'),
#   Calendar(week='13', day='5', hour='5', id='1355', lecture='Acquisizione ed elaborazione del suono', professor='Valle'),
#   Calendar(week='14', day='5', hour='5', id='1455', lecture='Acquisizione ed elaborazione del suono', professor='Valle'),
#   Calendar(week='18', day='5', hour='5', id='1855', lecture='Acquisizione ed elaborazione del suono', professor='Valle'),
#   Calendar(week='20', day='5', hour='1', id='2051', lecture='Acquisizione ed elaborazione di sequenze di immagini digitali', professor='Ghidelli'),
#   Calendar(week='24', day='5', hour='4', id='2454', lecture='Acquisizione ed elaborazione di sequenze di immagini digitali', professor='Ghidelli'),
#   Calendar(week='23', day='5', hour='5', id='2355', lecture='Acquisizione ed elaborazione di sequenze di immagini digitali', professor='Ghidelli'),
#   Calendar(week='24', day='5', hour='6', id='2456', lecture='Acquisizione ed elaborazione di sequenze di immagini digitali', professor='Ghidelli'),
#   Calendar(week='24', day='5', hour='7', id='2457', lecture='Acquisizione ed elaborazione di sequenze di immagini digitali', professor='Ghidelli'),
#   Calendar(week='24', day='5', hour='8', id='2458', lecture='Acquisizione ed elaborazione di sequenze di immagini digitali', professor='Ghidelli'),
#   Calendar(week='19', day='6', hour='1', id='1961', lecture='Acquisizione ed elaborazione di sequenze di immagini digitali', professor='Ghidelli'),
#   Calendar(week='21', day='6', hour='1', id='2161', lecture='Acquisizione ed elaborazione di sequenze di immagini digitali', professor='Ghidelli'),
#   Calendar(week='24', day='6', hour='2', id='2462', lecture='Acquisizione ed elaborazione di sequenze di immagini digitali', professor='Ghidelli'),
#   Calendar(week='20', day='6', hour='3', id='2063', lecture='Acquisizione ed elaborazione di sequenze di immagini digitali', professor='Ghidelli'),
#   Calendar(week='24', day='6', hour='3', id='2463', lecture='Acquisizione ed elaborazione di sequenze di immagini digitali', professor='Ghidelli'),
#   Calendar(week='22', day='6', hour='4', id='2264', lecture='Acquisizione ed elaborazione di sequenze di immagini digitali', professor='Ghidelli'),
#   Calendar(week='24', day='6', hour='4', id='2464', lecture='Acquisizione ed elaborazione di sequenze di immagini digitali', professor='Ghidelli'),
#   Calendar(week='18', day='6', hour='5', id='1865', lecture='Acquisizione ed elaborazione di sequenze di immagini digitali', professor='Ghidelli'),
#   Calendar(week='19', day='6', hour='5', id='1965', lecture='Acquisizione ed elaborazione di sequenze di immagini digitali', professor='Ghidelli'),
#   Calendar(week='20', day='6', hour='5', id='2065', lecture='Acquisizione ed elaborazione di sequenze di immagini digitali', professor='Ghidelli'),
#   Calendar(week='21', day='6', hour='5', id='2165', lecture='Acquisizione ed elaborazione di sequenze di immagini digitali', professor='Ghidelli'),
#   Calendar(week='22', day='6', hour='5', id='2265', lecture='Acquisizione ed elaborazione di sequenze di immagini digitali', professor='Ghidelli'),
#   Calendar(week='23', day='6', hour='5', id='2365', lecture='Acquisizione ed elaborazione di sequenze di immagini digitali', professor='Ghidelli'),
#   Calendar(week='24', day='6', hour='5', id='2465', lecture='Acquisizione ed elaborazione di sequenze di immagini digitali', professor='Ghidelli'),
#   Calendar(week='7', day='1', hour='3', id='713', lecture='Comunicazione pubblicitaria e comunicazione pubblica', professor='Gabardi'),
#   Calendar(week='9', day='5', hour='2', id='952', lecture='Comunicazione pubblicitaria e comunicazione pubblica', professor='Gabardi'),
#   Calendar(week='6', day='5', hour='3', id='653', lecture='Comunicazione pubblicitaria e comunicazione pubblica', professor='Gabardi'),
#   Calendar(week='7', day='5', hour='3', id='753', lecture='Comunicazione pubblicitaria e comunicazione pubblica', professor='Gabardi'),
#   Calendar(week='9', day='5', hour='3', id='953', lecture='Comunicazione pubblicitaria e comunicazione pubblica', professor='Gabardi'),
#   Calendar(week='7', day='5', hour='4', id='754', lecture='Comunicazione pubblicitaria e comunicazione pubblica', professor='Gabardi'),
#   Calendar(week='8', day='5', hour='5', id='855', lecture='Comunicazione pubblicitaria e comunicazione pubblica', professor='Gabardi'),
#   Calendar(week='9', day='5', hour='5', id='955', lecture='Comunicazione pubblicitaria e comunicazione pubblica', professor='Gabardi'),
#   Calendar(week='11', day='5', hour='5', id='1155', lecture='Comunicazione pubblicitaria e comunicazione pubblica', professor='Gabardi'),
#   Calendar(week='6', day='5', hour='7', id='657', lecture='Comunicazione pubblicitaria e comunicazione pubblica', professor='Gabardi'),
#   Calendar(week='8', day='5', hour='7', id='857', lecture='Comunicazione pubblicitaria e comunicazione pubblica', professor='Gabardi'),
#   Calendar(week='10', day='6', hour='2', id='1062', lecture='Comunicazione pubblicitaria e comunicazione pubblica', professor='Gabardi'),
#   Calendar(week='11', day='6', hour='3', id='1163', lecture='Comunicazione pubblicitaria e comunicazione pubblica', professor='Gabardi'),
#   Calendar(week='11', day='6', hour='5', id='1165', lecture='Comunicazione pubblicitaria e comunicazione pubblica', professor='Gabardi'),
#   Calendar(week='11', day='5', hour='2', id='1152', lecture='Semiologia e multimedialità', professor='Santangelo'),
#   Calendar(week='11', day='5', hour='6', id='1156', lecture='Semiologia e multimedialità', professor='Santangelo'),
#   Calendar(week='10', day='5', hour='7', id='1057', lecture='Semiologia e multimedialità', professor='Santangelo'),
#   Calendar(week='10', day='6', hour='1', id='1061', lecture='Semiologia e multimedialità', professor='Santangelo'),
#   Calendar(week='12', day='6', hour='2', id='1262', lecture='Semiologia e multimedialità', professor='Santangelo'),
#   Calendar(week='13', day='6', hour='2', id='1362', lecture='Semiologia e multimedialità', professor='Santangelo'),
#   Calendar(week='14', day='6', hour='2', id='1462', lecture='Semiologia e multimedialità', professor='Santangelo'),
#   Calendar(week='15', day='6', hour='2', id='1562', lecture='Semiologia e multimedialità', professor='Santangelo'),
#   Calendar(week='14', day='6', hour='4', id='1464', lecture='Semiologia e multimedialità', professor='Santangelo'),
#   Calendar(week='15', day='6', hour='4', id='1564', lecture='Semiologia e multimedialità', professor='Santangelo'),
#   Calendar(week='16', day='1', hour='1', id='1611', lecture='Crossmedia: articolazione delle scritture multimediali', professor='Taddeo'),
#   Calendar(week='16', day='1', hour='3', id='1613', lecture='Crossmedia: articolazione delle scritture multimediali', professor='Taddeo'),
#   Calendar(week='16', day='1', hour='4', id='1614', lecture='Crossmedia: articolazione delle scritture multimediali', professor='Taddeo'),
#   Calendar(week='16', day='2', hour='1', id='1621', lecture='Crossmedia: articolazione delle scritture multimediali', professor='Taddeo'),
#   Calendar(week='16', day='2', hour='8', id='1628', lecture='Crossmedia: articolazione delle scritture multimediali', professor='Taddeo'),
#   Calendar(week='16', day='3', hour='2', id='1632', lecture='Crossmedia: articolazione delle scritture multimediali', professor='Taddeo'),
#   Calendar(week='16', day='3', hour='5', id='1635', lecture='Crossmedia: articolazione delle scritture multimediali', professor='Taddeo'),
#   Calendar(week='16', day='3', hour='7', id='1637', lecture='Crossmedia: articolazione delle scritture multimediali', professor='Taddeo'),
#   Calendar(week='16', day='3', hour='8', id='1638', lecture='Crossmedia: articolazione delle scritture multimediali', professor='Taddeo'),
#   Calendar(week='16', day='4', hour='3', id='1643', lecture='Crossmedia: articolazione delle scritture multimediali', professor='Taddeo'),
#   Calendar(week='16', day='4', hour='4', id='1644', lecture='Crossmedia: articolazione delle scritture multimediali', professor='Taddeo'),
#   Calendar(week='16', day='4', hour='7', id='1647', lecture='Crossmedia: articolazione delle scritture multimediali', professor='Taddeo'),
#   Calendar(week='16', day='4', hour='8', id='1648', lecture='Crossmedia: articolazione delle scritture multimediali', professor='Taddeo'),
#   Calendar(week='16', day='5', hour='1', id='1651', lecture='Crossmedia: articolazione delle scritture multimediali', professor='Taddeo'),
#   Calendar(week='16', day='5', hour='2', id='1652', lecture='Crossmedia: articolazione delle scritture multimediali', professor='Taddeo'),
#   Calendar(week='16', day='5', hour='3', id='1653', lecture='Crossmedia: articolazione delle scritture multimediali', professor='Taddeo'),
#   Calendar(week='16', day='5', hour='6', id='1656', lecture='Crossmedia: articolazione delle scritture multimediali', professor='Taddeo'),
#   Calendar(week='16', day='6', hour='3', id='1663', lecture='Crossmedia: articolazione delle scritture multimediali', professor='Taddeo'),
#   Calendar(week='16', day='6', hour='4', id='1664', lecture='Crossmedia: articolazione delle scritture multimediali', professor='Taddeo'),
#   Calendar(week='16', day='6', hour='5', id='1665', lecture='Crossmedia: articolazione delle scritture multimediali', professor='Taddeo'),
#   Calendar(week='11', day='5', hour='1', id='1151', lecture='Grafica 3D', professor='Gribaudo'),
#   Calendar(week='12', day='5', hour='1', id='1251', lecture='Grafica 3D', professor='Gribaudo'),
#   Calendar(week='12', day='5', hour='2', id='1252', lecture='Grafica 3D', professor='Gribaudo'),
#   Calendar(week='10', day='5', hour='3', id='1053', lecture='Grafica 3D', professor='Gribaudo'),
#   Calendar(week='11', day='5', hour='3', id='1153', lecture='Grafica 3D', professor='Gribaudo'),
#   Calendar(week='12', day='5', hour='3', id='1253', lecture='Grafica 3D', professor='Gribaudo'),
#   Calendar(week='10', day='5', hour='5', id='1055', lecture='Grafica 3D', professor='Gribaudo'),
#   Calendar(week='12', day='5', hour='8', id='1258', lecture='Grafica 3D', professor='Gribaudo'),
#   Calendar(week='12', day='6', hour='1', id='1261', lecture='Grafica 3D', professor='Gribaudo'),
#   Calendar(week='10', day='6', hour='3', id='1063', lecture='Grafica 3D', professor='Gribaudo'),
#   Calendar(week='12', day='6', hour='3', id='1263', lecture='Grafica 3D', professor='Gribaudo'),
#   Calendar(week='13', day='6', hour='3', id='1363', lecture='Grafica 3D', professor='Gribaudo'),
#   Calendar(week='10', day='6', hour='4', id='1064', lecture='Grafica 3D', professor='Gribaudo'),
#   Calendar(week='11', day='6', hour='4', id='1164', lecture='Grafica 3D', professor='Gribaudo'),
#   Calendar(week='12', day='6', hour='4', id='1264', lecture='Grafica 3D', professor='Gribaudo'),
#   Calendar(week='13', day='6', hour='4', id='1364', lecture='Grafica 3D', professor='Gribaudo'),
#   Calendar(week='9', day='6', hour='5', id='965', lecture='Grafica 3D', professor='Gribaudo'),
#   Calendar(week='10', day='6', hour='5', id='1065', lecture='Grafica 3D', professor='Gribaudo'),
#   Calendar(week='12', day='6', hour='5', id='1265', lecture='Grafica 3D', professor='Gribaudo'),
#   Calendar(week='13', day='6', hour='5', id='1365', lecture='Grafica 3D', professor='Gribaudo'),
#   Calendar(week='20', day='5', hour='2', id='2052', lecture='Progettazione e sviluppo di applicazioni web su dispositivi mobile I', professor='Pozzato'),
#   Calendar(week='20', day='5', hour='6', id='2056', lecture='Progettazione e sviluppo di applicazioni web su dispositivi mobile I', professor='Pozzato'),
#   Calendar(week='20', day='5', hour='7', id='2057', lecture='Progettazione e sviluppo di applicazioni web su dispositivi mobile I', professor='Pozzato'),
#   Calendar(week='19', day='5', hour='8', id='1958', lecture='Progettazione e sviluppo di applicazioni web su dispositivi mobile I', professor='Pozzato'),
#   Calendar(week='20', day='5', hour='8', id='2058', lecture='Progettazione e sviluppo di applicazioni web su dispositivi mobile I', professor='Pozzato'),
#   Calendar(week='20', day='6', hour='1', id='2061', lecture='Progettazione e sviluppo di applicazioni web su dispositivi mobile I', professor='Pozzato'),
#   Calendar(week='19', day='6', hour='2', id='1962', lecture='Progettazione e sviluppo di applicazioni web su dispositivi mobile I', professor='Pozzato'),
#   Calendar(week='20', day='6', hour='2', id='2062', lecture='Progettazione e sviluppo di applicazioni web su dispositivi mobile I', professor='Pozzato'),
#   Calendar(week='19', day='6', hour='3', id='1963', lecture='Progettazione e sviluppo di applicazioni web su dispositivi mobile I', professor='Pozzato'),
#   Calendar(week='19', day='6', hour='4', id='1964', lecture='Progettazione e sviluppo di applicazioni web su dispositivi mobile I', professor='Pozzato'),
#   Calendar(week='24', day='5', hour='1', id='2451', lecture='Progettazione e sviluppo di applicazioni web su dispositivi mobile II', professor='Schifanella'),
#   Calendar(week='24', day='5', hour='2', id='2452', lecture='Progettazione e sviluppo di applicazioni web su dispositivi mobile II', professor='Schifanella'),
#   Calendar(week='21', day='5', hour='3', id='2153', lecture='Progettazione e sviluppo di applicazioni web su dispositivi mobile II', professor='Schifanella'),
#   Calendar(week='24', day='5', hour='3', id='2453', lecture='Progettazione e sviluppo di applicazioni web su dispositivi mobile II', professor='Schifanella'),
#   Calendar(week='24', day='5', hour='5', id='2455', lecture='Progettazione e sviluppo di applicazioni web su dispositivi mobile II', professor='Schifanella'),
#   Calendar(week='23', day='6', hour='1', id='2361', lecture='Progettazione e sviluppo di applicazioni web su dispositivi mobile II', professor='Schifanella'),
#   Calendar(week='24', day='6', hour='1', id='2461', lecture='Progettazione e sviluppo di applicazioni web su dispositivi mobile II', professor='Schifanella'),
#   Calendar(week='23', day='6', hour='2', id='2362', lecture='Progettazione e sviluppo di applicazioni web su dispositivi mobile II', professor='Schifanella'),
#   Calendar(week='23', day='6', hour='3', id='2363', lecture='Progettazione e sviluppo di applicazioni web su dispositivi mobile II', professor='Schifanella'),
#   Calendar(week='23', day='6', hour='4', id='2364', lecture='Progettazione e sviluppo di applicazioni web su dispositivi mobile II', professor='Schifanella'),
#   Calendar(week='22', day='5', hour='1', id='2251', lecture='La gestione delle risorse umane', professor='Lombardo'),
#   Calendar(week='23', day='5', hour='1', id='2351', lecture='La gestione delle risorse umane', professor='Lombardo'),
#   Calendar(week='21', day='5', hour='2', id='2152', lecture='La gestione delle risorse umane', professor='Lombardo'),
#   Calendar(week='17', day='5', hour='3', id='1753', lecture='La gestione delle risorse umane', professor='Lombardo'),
#   Calendar(week='18', day='5', hour='3', id='1853', lecture='La gestione delle risorse umane', professor='Lombardo'),
#   Calendar(week='19', day='5', hour='3', id='1953', lecture='La gestione delle risorse umane', professor='Lombardo'),
#   Calendar(week='17', day='5', hour='4', id='1754', lecture='La gestione delle risorse umane', professor='Lombardo'),
#   Calendar(week='21', day='5', hour='5', id='2155', lecture='La gestione delle risorse umane', professor='Lombardo'),
#   Calendar(week='21', day='5', hour='7', id='2157', lecture='La gestione delle risorse umane', professor='Lombardo'),
#   Calendar(week='18', day='6', hour='3', id='1863', lecture='La gestione delle risorse umane', professor='Lombardo'),
#   Calendar(week='18', day='5', hour='1', id='1851', lecture='I vincoli giuridici del progetto: diritto dei media', professor='Travostino'),
#   Calendar(week='17', day='5', hour='2', id='1752', lecture='I vincoli giuridici del progetto: diritto dei media', professor='Travostino'),
#   Calendar(week='20', day='5', hour='3', id='2053', lecture='I vincoli giuridici del progetto: diritto dei media', professor='Travostino'),
#   Calendar(week='20', day='5', hour='4', id='2054', lecture='I vincoli giuridici del progetto: diritto dei media', professor='Travostino'),
#   Calendar(week='14', day='6', hour='1', id='1461', lecture='I vincoli giuridici del progetto: diritto dei media', professor='Travostino'),
#   Calendar(week='18', day='6', hour='2', id='1862', lecture='I vincoli giuridici del progetto: diritto dei media', professor='Travostino'),
#   Calendar(week='17', day='6', hour='3', id='1763', lecture='I vincoli giuridici del progetto: diritto dei media', professor='Travostino'),
#   Calendar(week='17', day='6', hour='4', id='1764', lecture='I vincoli giuridici del progetto: diritto dei media', professor='Travostino'),
#   Calendar(week='18', day='6', hour='4', id='1864', lecture='I vincoli giuridici del progetto: diritto dei media', professor='Travostino'),
#   Calendar(week='14', day='6', hour='5', id='1465', lecture='I vincoli giuridici del progetto: diritto dei media', professor='Travostino')]}

# %%
# Moving the parsed_content inside a Pandas Dataframe
df = pd.DataFrame(parsed_content['Answer_1'])

# Conversion of type inside the datadframe (otherwise all the data will be imported as string)
df = df.astype({'week': 'int64', 'day': 'int64', 'hour': 'int64'})

# Setting DataFrame indexes
df = df.set_index(['week','day','hour']).drop('id',axis=1)

# Sorting based on previously defined indexes
df = df.sort_index()

# Replacing the day number with a better (and more readable) rapresentation
df = df.replace({'day':{'1':'Lun (1)','2':'Mar (2)','3':'Mer (3)',
                   '4':'Gio (4)','5':'Ven (5)','6':'Sab (6)'}})

df['Lecture'] = df['lecture'] + ": " + df['professor']
df = df.drop(['lecture','professor'], axis=1)

# %%
# Checking if the data manipulation was correct
df
# Out:
#                                                          Lecture
# week day hour
# 1    5   1                                               Intro:
#          2                                               Intro:
#          3     Fondamenti di ICT e Paradigmi di Programmazion...
#          4                          Project Management: Muzzetto
#          5                          Project Management: Muzzetto
# ...                                                          ...
# 24   6   1     Progettazione e sviluppo di applicazioni web s...
#          2     Acquisizione ed elaborazione di sequenze di im...
#          3     Acquisizione ed elaborazione di sequenze di im...
#          4     Acquisizione ed elaborazione di sequenze di im...
#          5     Acquisizione ed elaborazione di sequenze di im...
#
# [364 rows x 1 columns]

# %% [markdown]
# ## Build Excel Timetable
#
# In this section, it's possible to export the timetable just transpiled into an Excel file, in order to improve human-like readability.

# %%
timetable = df.unstack('hour')
timetable
# Out:
#                                                     Lecture  \
# hour                                                      1
# week day
# 1    5                                              Intro:
#      6    Fondamenti di ICT e Paradigmi di Programmazion...
# 2    5                         Project Management: Muzzetto
#      6                Progettazione di basi di dati: Mazzei
# 3    5                         Project Management: Muzzetto
#      6    Fondamenti di ICT e Paradigmi di Programmazion...
# 4    5    Fondamenti di ICT e Paradigmi di Programmazion...
#      6                Progettazione di basi di dati: Mazzei
# 5    5    Ambienti di sviluppo e linguaggi client-side p...
#      6    Ambienti di sviluppo e linguaggi client-side p...
# 6    5                         Marketing digitale: Muzzetto
#      6                         Marketing digitale: Muzzetto
# 7    1                         Marketing digitale: Muzzetto
#      2    Acquisizione ed elaborazione di immagini stati...
#      3    Tecniche e strumenti di Marketing digitale: Za...
#      4    Ambienti di sviluppo e linguaggi client-side p...
#      5    Tecniche e strumenti di Marketing digitale: Za...
#      6    Tecniche e strumenti di Marketing digitale: Za...
# 8    5    Tecniche e strumenti di Marketing digitale: Za...
#      6                            Linguaggi di markup: Gena
# 9    5                            Linguaggi di markup: Gena
#      6    Accessibilità e usabilità nella progettazione ...
# 10   5    Strumenti e metodi di interazione nei Social m...
#      6              Semiologia e multimedialità: Santangelo
# 11   5                                 Grafica 3D: Gribaudo
#      6    Accessibilità e usabilità nella progettazione ...
# 12   5                                 Grafica 3D: Gribaudo
#      6                                 Grafica 3D: Gribaudo
# 13   5        Acquisizione ed elaborazione del suono: Valle
#      6                                                  NaN
# 14   5        Acquisizione ed elaborazione del suono: Valle
#      6    I vincoli giuridici del progetto: diritto dei ...
# 15   5        Acquisizione ed elaborazione del suono: Valle
#      6              Elementi di fotografia digitale: Vargiu
# 16   1    Crossmedia: articolazione delle scritture mult...
#      2    Crossmedia: articolazione delle scritture mult...
#      3     Introduzione al social media management: Suppini
#      4     Introduzione al social media management: Suppini
#      5    Crossmedia: articolazione delle scritture mult...
#      6              Elementi di fotografia digitale: Vargiu
# 17   5                   La gestione della qualità: Tomatis
#      6    Progettazione grafica e design di interfacce: ...
# 18   5    I vincoli giuridici del progetto: diritto dei ...
#      6              Elementi di fotografia digitale: Vargiu
# 19   5                   La gestione della qualità: Tomatis
#      6    Acquisizione ed elaborazione di sequenze di im...
# 20   5    Acquisizione ed elaborazione di sequenze di im...
#      6    Progettazione e sviluppo di applicazioni web s...
# 21   5                   La gestione della qualità: Tomatis
#      6    Acquisizione ed elaborazione di sequenze di im...
# 22   5            La gestione delle risorse umane: Lombardo
#      6           Tecnologie server-side per il web: Damiano
# 23   5            La gestione delle risorse umane: Lombardo
#      6    Progettazione e sviluppo di applicazioni web s...
# 24   5    Progettazione e sviluppo di applicazioni web s...
#      6    Progettazione e sviluppo di applicazioni web s...
#
#                                                              \
# hour                                                      2
# week day
# 1    5                                              Intro:
#      6                Progettazione di basi di dati: Mazzei
# 2    5                         Project Management: Muzzetto
#      6                Progettazione di basi di dati: Mazzei
# 3    5                         Project Management: Muzzetto
#      6                Progettazione di basi di dati: Mazzei
# 4    5    Fondamenti di ICT e Paradigmi di Programmazion...
#      6    Ambienti di sviluppo e linguaggi client-side p...
# 5    5    Ambienti di sviluppo e linguaggi client-side p...
#      6                         Project Management: Muzzetto
# 6    5                                           Recupero:
#      6                                           Recupero:
# 7    1                            Linguaggi di markup: Gena
#      2                            Linguaggi di markup: Gena
#      3    Acquisizione ed elaborazione di immagini stati...
#      4    Ambienti di sviluppo e linguaggi client-side p...
#      5                            Linguaggi di markup: Gena
#      6    Tecniche e strumenti di Marketing digitale: Za...
# 8    5    Accessibilità e usabilità nella progettazione ...
#      6    Acquisizione ed elaborazione di immagini stati...
# 9    5    Comunicazione pubblicitaria e comunicazione pu...
#      6    Acquisizione ed elaborazione di immagini stati...
# 10   5    Strumenti e metodi di interazione nei Social m...
#      6    Comunicazione pubblicitaria e comunicazione pu...
# 11   5              Semiologia e multimedialità: Santangelo
#      6    Accessibilità e usabilità nella progettazione ...
# 12   5                                 Grafica 3D: Gribaudo
#      6              Semiologia e multimedialità: Santangelo
# 13   5        Acquisizione ed elaborazione del suono: Valle
#      6              Semiologia e multimedialità: Santangelo
# 14   5        Acquisizione ed elaborazione del suono: Valle
#      6              Semiologia e multimedialità: Santangelo
# 15   5        Acquisizione ed elaborazione del suono: Valle
#      6              Semiologia e multimedialità: Santangelo
# 16   1    Strumenti e metodi di interazione nei Social m...
#      2     Introduzione al social media management: Suppini
#      3    Crossmedia: articolazione delle scritture mult...
#      4     Introduzione al social media management: Suppini
#      5    Crossmedia: articolazione delle scritture mult...
#      6    Strumenti e metodi di interazione nei Social m...
# 17   5    I vincoli giuridici del progetto: diritto dei ...
#      6                   La gestione della qualità: Tomatis
# 18   5                   La gestione della qualità: Tomatis
#      6    I vincoli giuridici del progetto: diritto dei ...
# 19   5           Tecnologie server-side per il web: Damiano
#      6    Progettazione e sviluppo di applicazioni web s...
# 20   5    Progettazione e sviluppo di applicazioni web s...
#      6    Progettazione e sviluppo di applicazioni web s...
# 21   5            La gestione delle risorse umane: Lombardo
#      6           Tecnologie server-side per il web: Damiano
# 22   5                   La gestione della qualità: Tomatis
#      6           Tecnologie server-side per il web: Damiano
# 23   5           Tecnologie server-side per il web: Damiano
#      6    Progettazione e sviluppo di applicazioni web s...
# 24   5    Progettazione e sviluppo di applicazioni web s...
#      6    Acquisizione ed elaborazione di sequenze di im...
#
#                                                              \
# hour                                                      3
# week day
# 1    5    Fondamenti di ICT e Paradigmi di Programmazion...
#      6                Progettazione di basi di dati: Mazzei
# 2    5                Progettazione di basi di dati: Mazzei
#      6                         Project Management: Muzzetto
# 3    5                         Project Management: Muzzetto
#      6    Fondamenti di ICT e Paradigmi di Programmazion...
# 4    5                Progettazione di basi di dati: Mazzei
#      6                Progettazione di basi di dati: Mazzei
# 5    5    Ambienti di sviluppo e linguaggi client-side p...
#      6    Ambienti di sviluppo e linguaggi client-side p...
# 6    5    Comunicazione pubblicitaria e comunicazione pu...
#      6                                           Recupero:
# 7    1    Comunicazione pubblicitaria e comunicazione pu...
#      2                                                  NaN
#      3                            Linguaggi di markup: Gena
#      4                            Linguaggi di markup: Gena
#      5    Comunicazione pubblicitaria e comunicazione pu...
#      6    Acquisizione ed elaborazione di immagini stati...
# 8    5    Ambienti di sviluppo e linguaggi client-side p...
#      6    Tecniche e strumenti di Marketing digitale: Za...
# 9    5    Comunicazione pubblicitaria e comunicazione pu...
#      6    Acquisizione ed elaborazione di immagini stati...
# 10   5                                 Grafica 3D: Gribaudo
#      6                                 Grafica 3D: Gribaudo
# 11   5                                 Grafica 3D: Gribaudo
#      6    Comunicazione pubblicitaria e comunicazione pu...
# 12   5                                 Grafica 3D: Gribaudo
#      6                                 Grafica 3D: Gribaudo
# 13   5    Tecniche e strumenti di Marketing digitale: Za...
#      6                                 Grafica 3D: Gribaudo
# 14   5        Acquisizione ed elaborazione del suono: Valle
#      6    Risorse digitali per il progetto: collaborazio...
# 15   5    Risorse digitali per il progetto: collaborazio...
#      6    Strumenti e metodi di interazione nei Social m...
# 16   1    Crossmedia: articolazione delle scritture mult...
#      2     Introduzione al social media management: Suppini
#      3     Introduzione al social media management: Suppini
#      4    Crossmedia: articolazione delle scritture mult...
#      5    Crossmedia: articolazione delle scritture mult...
#      6    Crossmedia: articolazione delle scritture mult...
# 17   5            La gestione delle risorse umane: Lombardo
#      6    I vincoli giuridici del progetto: diritto dei ...
# 18   5            La gestione delle risorse umane: Lombardo
#      6            La gestione delle risorse umane: Lombardo
# 19   5            La gestione delle risorse umane: Lombardo
#      6    Progettazione e sviluppo di applicazioni web s...
# 20   5    I vincoli giuridici del progetto: diritto dei ...
#      6    Acquisizione ed elaborazione di sequenze di im...
# 21   5    Progettazione e sviluppo di applicazioni web s...
#      6           Tecnologie server-side per il web: Damiano
# 22   5                   La gestione della qualità: Tomatis
#      6           Tecnologie server-side per il web: Damiano
# 23   5    Progettazione grafica e design di interfacce: ...
#      6    Progettazione e sviluppo di applicazioni web s...
# 24   5    Progettazione e sviluppo di applicazioni web s...
#      6    Acquisizione ed elaborazione di sequenze di im...
#
#                                                              \
# hour                                                      4
# week day
# 1    5                         Project Management: Muzzetto
#      6                Progettazione di basi di dati: Mazzei
# 2    5                Progettazione di basi di dati: Mazzei
#      6                Progettazione di basi di dati: Mazzei
# 3    5    Fondamenti di ICT e Paradigmi di Programmazion...
#      6                Progettazione di basi di dati: Mazzei
# 4    5    Fondamenti di ICT e Paradigmi di Programmazion...
#      6                Progettazione di basi di dati: Mazzei
# 5    5                         Project Management: Muzzetto
#      6    Ambienti di sviluppo e linguaggi client-side p...
# 6    5                         Marketing digitale: Muzzetto
#      6    Acquisizione ed elaborazione di immagini stati...
# 7    1                         Marketing digitale: Muzzetto
#      2                                                  NaN
#      3    Ambienti di sviluppo e linguaggi client-side p...
#      4                            Linguaggi di markup: Gena
#      5    Comunicazione pubblicitaria e comunicazione pu...
#      6    Acquisizione ed elaborazione di immagini stati...
# 8    5    Ambienti di sviluppo e linguaggi client-side p...
#      6    Accessibilità e usabilità nella progettazione ...
# 9    5    Ambienti di sviluppo e linguaggi client-side p...
#      6    Acquisizione ed elaborazione di immagini stati...
# 10   5    Accessibilità e usabilità nella progettazione ...
#      6                                 Grafica 3D: Gribaudo
# 11   5    Strumenti e metodi di interazione nei Social m...
#      6                                 Grafica 3D: Gribaudo
# 12   5    Accessibilità e usabilità nella progettazione ...
#      6                                 Grafica 3D: Gribaudo
# 13   5    Risorse digitali per il progetto: collaborazio...
#      6                                 Grafica 3D: Gribaudo
# 14   5    Risorse digitali per il progetto: collaborazio...
#      6              Semiologia e multimedialità: Santangelo
# 15   5    Risorse digitali per il progetto: collaborazio...
#      6              Semiologia e multimedialità: Santangelo
# 16   1    Crossmedia: articolazione delle scritture mult...
#      2     Introduzione al social media management: Suppini
#      3    Strumenti e metodi di interazione nei Social m...
#      4    Crossmedia: articolazione delle scritture mult...
#      5    Strumenti e metodi di interazione nei Social m...
#      6    Crossmedia: articolazione delle scritture mult...
# 17   5            La gestione delle risorse umane: Lombardo
#      6    I vincoli giuridici del progetto: diritto dei ...
# 18   5    Risorse digitali per il progetto: collaborazio...
#      6    I vincoli giuridici del progetto: diritto dei ...
# 19   5           Tecnologie server-side per il web: Damiano
#      6    Progettazione e sviluppo di applicazioni web s...
# 20   5    I vincoli giuridici del progetto: diritto dei ...
#      6           Tecnologie server-side per il web: Damiano
# 21   5           Tecnologie server-side per il web: Damiano
#      6           Tecnologie server-side per il web: Damiano
# 22   5                                                  NaN
#      6    Acquisizione ed elaborazione di sequenze di im...
# 23   5    Progettazione grafica e design di interfacce: ...
#      6    Progettazione e sviluppo di applicazioni web s...
# 24   5    Acquisizione ed elaborazione di sequenze di im...
#      6    Acquisizione ed elaborazione di sequenze di im...
#
#                                                              \
# hour                                                      5
# week day
# 1    5                         Project Management: Muzzetto
#      6                Progettazione di basi di dati: Mazzei
# 2    5    Fondamenti di ICT e Paradigmi di Programmazion...
#      6                Progettazione di basi di dati: Mazzei
# 3    5    Fondamenti di ICT e Paradigmi di Programmazion...
#      6                Progettazione di basi di dati: Mazzei
# 4    5                         Project Management: Muzzetto
#      6                Progettazione di basi di dati: Mazzei
# 5    5    Ambienti di sviluppo e linguaggi client-side p...
#      6                                           Recupero:
# 6    5    Accessibilità e usabilità nella progettazione ...
#      6                            Linguaggi di markup: Gena
# 7    1                         Marketing digitale: Muzzetto
#      2                         Marketing digitale: Muzzetto
#      3                            Linguaggi di markup: Gena
#      4                            Linguaggi di markup: Gena
#      5    Acquisizione ed elaborazione di immagini stati...
#      6    Accessibilità e usabilità nella progettazione ...
# 8    5    Comunicazione pubblicitaria e comunicazione pu...
#      6    Tecniche e strumenti di Marketing digitale: Za...
# 9    5    Comunicazione pubblicitaria e comunicazione pu...
#      6                                 Grafica 3D: Gribaudo
# 10   5                                 Grafica 3D: Gribaudo
#      6                                 Grafica 3D: Gribaudo
# 11   5    Comunicazione pubblicitaria e comunicazione pu...
#      6    Comunicazione pubblicitaria e comunicazione pu...
# 12   5    Accessibilità e usabilità nella progettazione ...
#      6                                 Grafica 3D: Gribaudo
# 13   5        Acquisizione ed elaborazione del suono: Valle
#      6                                 Grafica 3D: Gribaudo
# 14   5        Acquisizione ed elaborazione del suono: Valle
#      6    I vincoli giuridici del progetto: diritto dei ...
# 15   5    Risorse digitali per il progetto: collaborazio...
#      6                                                  NaN
# 16   1     Introduzione al social media management: Suppini
#      2    Strumenti e metodi di interazione nei Social m...
#      3    Crossmedia: articolazione delle scritture mult...
#      4     Introduzione al social media management: Suppini
#      5    Strumenti e metodi di interazione nei Social m...
#      6    Crossmedia: articolazione delle scritture mult...
# 17   5    Risorse digitali per il progetto: collaborazio...
#      6    Progettazione grafica e design di interfacce: ...
# 18   5        Acquisizione ed elaborazione del suono: Valle
#      6    Acquisizione ed elaborazione di sequenze di im...
# 19   5           Tecnologie server-side per il web: Damiano
#      6    Acquisizione ed elaborazione di sequenze di im...
# 20   5           Tecnologie server-side per il web: Damiano
#      6    Acquisizione ed elaborazione di sequenze di im...
# 21   5            La gestione delle risorse umane: Lombardo
#      6    Acquisizione ed elaborazione di sequenze di im...
# 22   5                   La gestione della qualità: Tomatis
#      6    Acquisizione ed elaborazione di sequenze di im...
# 23   5    Acquisizione ed elaborazione di sequenze di im...
#      6    Acquisizione ed elaborazione di sequenze di im...
# 24   5    Progettazione e sviluppo di applicazioni web s...
#      6    Acquisizione ed elaborazione di sequenze di im...
#
#                                                              \
# hour                                                      6
# week day
# 1    5                         Project Management: Muzzetto
#      6                                                  NaN
# 2    5                         Project Management: Muzzetto
#      6                                                  NaN
# 3    5                Progettazione di basi di dati: Mazzei
#      6                                                  NaN
# 4    5    Ambienti di sviluppo e linguaggi client-side p...
#      6                                                  NaN
# 5    5                                                  NaN
#      6                                                  NaN
# 6    5                         Marketing digitale: Muzzetto
#      6                                                  NaN
# 7    1                            Linguaggi di markup: Gena
#      2                         Marketing digitale: Muzzetto
#      3                            Linguaggi di markup: Gena
#      4    Ambienti di sviluppo e linguaggi client-side p...
#      5    Acquisizione ed elaborazione di immagini stati...
#      6                                                  NaN
# 8    5    Accessibilità e usabilità nella progettazione ...
#      6                                                  NaN
# 9    5                            Linguaggi di markup: Gena
#      6                                                  NaN
# 10   5                            Linguaggi di markup: Gena
#      6                                                  NaN
# 11   5              Semiologia e multimedialità: Santangelo
#      6                                                  NaN
# 12   5    Accessibilità e usabilità nella progettazione ...
#      6                                                  NaN
# 13   5                                                  NaN
#      6                                                  NaN
# 14   5              Elementi di fotografia digitale: Vargiu
#      6                                                  NaN
# 15   5    Strumenti e metodi di interazione nei Social m...
#      6                                                  NaN
# 16   1     Introduzione al social media management: Suppini
#      2     Introduzione al social media management: Suppini
#      3     Introduzione al social media management: Suppini
#      4    Strumenti e metodi di interazione nei Social m...
#      5    Crossmedia: articolazione delle scritture mult...
#      6                                                  NaN
# 17   5              Elementi di fotografia digitale: Vargiu
#      6                                                  NaN
# 18   5    Progettazione grafica e design di interfacce: ...
#      6                                                  NaN
# 19   5    Progettazione grafica e design di interfacce: ...
#      6                                                  NaN
# 20   5    Progettazione e sviluppo di applicazioni web s...
#      6                                                  NaN
# 21   5           Tecnologie server-side per il web: Damiano
#      6                                                  NaN
# 22   5           Tecnologie server-side per il web: Damiano
#      6                                                  NaN
# 23   5    Progettazione grafica e design di interfacce: ...
#      6                                                  NaN
# 24   5    Acquisizione ed elaborazione di sequenze di im...
#      6                                                  NaN
#
#                                                              \
# hour                                                      7
# week day
# 1    5    Fondamenti di ICT e Paradigmi di Programmazion...
#      6                                                  NaN
# 2    5                         Project Management: Muzzetto
#      6                                                  NaN
# 3    5    Fondamenti di ICT e Paradigmi di Programmazion...
#      6                                                  NaN
# 4    5    Ambienti di sviluppo e linguaggi client-side p...
#      6                                                  NaN
# 5    5                                                  NaN
#      6                                                  NaN
# 6    5    Comunicazione pubblicitaria e comunicazione pu...
#      6                                                  NaN
# 7    1                                                  NaN
#      2    Acquisizione ed elaborazione di immagini stati...
#      3    Ambienti di sviluppo e linguaggi client-side p...
#      4    Tecniche e strumenti di Marketing digitale: Za...
#      5                            Linguaggi di markup: Gena
#      6                                                  NaN
# 8    5    Comunicazione pubblicitaria e comunicazione pu...
#      6                                                  NaN
# 9    5    Acquisizione ed elaborazione di immagini stati...
#      6                                                  NaN
# 10   5              Semiologia e multimedialità: Santangelo
#      6                                                  NaN
# 11   5    Accessibilità e usabilità nella progettazione ...
#      6                                                  NaN
# 12   5              Elementi di fotografia digitale: Vargiu
#      6                                                  NaN
# 13   5              Elementi di fotografia digitale: Vargiu
#      6                                                  NaN
# 14   5    Risorse digitali per il progetto: collaborazio...
#      6                                                  NaN
# 15   5              Elementi di fotografia digitale: Vargiu
#      6                                                  NaN
# 16   1     Introduzione al social media management: Suppini
#      2                   La gestione della qualità: Tomatis
#      3    Crossmedia: articolazione delle scritture mult...
#      4    Crossmedia: articolazione delle scritture mult...
#      5    Strumenti e metodi di interazione nei Social m...
#      6                                                  NaN
# 17   5           Tecnologie server-side per il web: Damiano
#      6                                                  NaN
# 18   5    Progettazione grafica e design di interfacce: ...
#      6                                                  NaN
# 19   5    Progettazione grafica e design di interfacce: ...
#      6                                                  NaN
# 20   5    Progettazione e sviluppo di applicazioni web s...
#      6                                                  NaN
# 21   5            La gestione delle risorse umane: Lombardo
#      6                                                  NaN
# 22   5           Tecnologie server-side per il web: Damiano
#      6                                                  NaN
# 23   5    Progettazione grafica e design di interfacce: ...
#      6                                                  NaN
# 24   5    Acquisizione ed elaborazione di sequenze di im...
#      6                                                  NaN
#
#
# hour                                                      8
# week day
# 1    5    Fondamenti di ICT e Paradigmi di Programmazion...
#      6                                                  NaN
# 2    5                Progettazione di basi di dati: Mazzei
#      6                                                  NaN
# 3    5    Fondamenti di ICT e Paradigmi di Programmazion...
#      6                                                  NaN
# 4    5    Ambienti di sviluppo e linguaggi client-side p...
#      6                                                  NaN
# 5    5                                                  NaN
#      6                                                  NaN
# 6    5                         Marketing digitale: Muzzetto
#      6                                                  NaN
# 7    1                                                  NaN
#      2                            Linguaggi di markup: Gena
#      3    Ambienti di sviluppo e linguaggi client-side p...
#      4    Acquisizione ed elaborazione di immagini stati...
#      5                            Linguaggi di markup: Gena
#      6                                                  NaN
# 8    5    Tecniche e strumenti di Marketing digitale: Za...
#      6                                                  NaN
# 9    5                            Linguaggi di markup: Gena
#      6                                                  NaN
# 10   5                            Linguaggi di markup: Gena
#      6                                                  NaN
# 11   5    Accessibilità e usabilità nella progettazione ...
#      6                                                  NaN
# 12   5                                 Grafica 3D: Gribaudo
#      6                                                  NaN
# 13   5    Risorse digitali per il progetto: collaborazio...
#      6                                                  NaN
# 14   5    Strumenti e metodi di interazione nei Social m...
#      6                                                  NaN
# 15   5              Elementi di fotografia digitale: Vargiu
#      6                                                  NaN
# 16   1     Introduzione al social media management: Suppini
#      2    Crossmedia: articolazione delle scritture mult...
#      3    Crossmedia: articolazione delle scritture mult...
#      4    Crossmedia: articolazione delle scritture mult...
#      5                   La gestione della qualità: Tomatis
#      6                                                  NaN
# 17   5              Elementi di fotografia digitale: Vargiu
#      6                                                  NaN
# 18   5           Tecnologie server-side per il web: Damiano
#      6                                                  NaN
# 19   5    Progettazione e sviluppo di applicazioni web s...
#      6                                                  NaN
# 20   5    Progettazione e sviluppo di applicazioni web s...
#      6                                                  NaN
# 21   5           Tecnologie server-side per il web: Damiano
#      6                                                  NaN
# 22   5           Tecnologie server-side per il web: Damiano
#      6                                                  NaN
# 23   5                                                  NaN
#      6                                                  NaN
# 24   5    Acquisizione ed elaborazione di sequenze di im...
#      6                                                  NaN

# %%
output_path = "output/timetable.xlsx"

# Instaciating a ExcelWriter to save the output file.
writer = pd.ExcelWriter(output_path, engine='xlsxwriter')

# Exporting timetable in the excel file Timetable.xlsx inside Sheet1.
timetable.to_excel(writer, sheet_name="Sheet1")

print("Timetable transpiled into output/timetable.xlsx.")
# Out:
# Timetable transpiled into output/timetable.xlsx.

# %% [markdown]
# ### Formatting the Timetable
#
# If needed, it's possible to conditionally format the timetable cells using the following python script.

# %%
# Getting the xlsxwriter workbook and worksheet objects.
workbook  = writer.book
worksheet = writer.sheets['Sheet1']

# Format 1. Light red fill with dark red text.
format1 = workbook.add_format({'bg_color': '#FFC7CE','font_color': '#9C0006'})

# Format 2. Green fill with dark green text.
format2 = workbook.add_format({'bg_color': '#C6EFCE','font_color': '#006100'})
    
# Format 3. Yellow fill with brown text.
format3 = workbook.add_format({'bg_color': '#FFEB9B','font_color': '#9D744F'})
    
# Format 4. Orange fill with light purple text.
format4 = workbook.add_format({'bg_color': '#FFCC99','font_color': '#766882'})

worksheet.conditional_format('C4:J59', {'type': 'text',
                                        'criteria': 'containing',
                                        'value': 'Intro:',
                                        'format': format1})

worksheet.conditional_format('C4:J59', {'type': 'text',
                                        'criteria': 'containing',
                                        'value': 'Recupero',
                                        'format': format2})

# Close the Pandas Excel writer and output the Excel file.
writer.save()

print("Timetable formatting completed.")
# Out:
# Timetable formatting completed.
